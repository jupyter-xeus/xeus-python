# %%
a = 3
a

# %%
a

# %%
a += 6

# %%
print(a)

# %%
a

# %%
b = 89

def test(x):
    return x * 2

test(b)

# %%
test(4)

# %%
print(a)

# %%
import missing_module

# %%
b = {"a": 2, "b": 3}

# %%
b

# %%
print(b["a"])

# %%
print(b["c"])

# %%
import time

for x in range(10):
    print(x)
    time.sleep(1)

# %%
import sys

print("Error !!", file=sys.stderr)
